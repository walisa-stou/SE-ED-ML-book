# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
mydata= pd.read_csv('/content/sample_data/lungcancer.csv')
mydata.head(10)
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
# 5      F   75        1               2        1              1
# 6      M   52        2               1        1              1
# 7      F   51        2               2        2              2
# 8      F   68        2               1        2              1
# 9      M   53        2               2        2              2
#
#    CHRONIC_DISEASE  ALLERGY   WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                1         1         2                  2         2
# 1                2         2         1                  1         1
# ...

# %%
mydata['GENDER'].value_counts()
# Out:
# M    162
# F    147
# Name: GENDER, dtype: int64

# %%
mydata['RESULT'].value_counts()
# Out:
# YES    270
# NO      39
# Name: RESULT, dtype: int64

# %%
# @title GENDER

from matplotlib import pyplot as plt
import seaborn as sns
mydata.groupby('GENDER').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title RESULT

from matplotlib import pyplot as plt
import seaborn as sns
mydata.groupby('RESULT').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
mydata.describe()
# Out:
#               AGE     SMOKING  YELLOW_FINGERS     ANXIETY  PEER_PRESSURE  \
# count  309.000000  309.000000      309.000000  309.000000     309.000000
# mean    62.673139    1.563107        1.569579    1.498382       1.501618
# std      8.210301    0.496806        0.495938    0.500808       0.500808
# min     21.000000    1.000000        1.000000    1.000000       1.000000
# 25%     57.000000    1.000000        1.000000    1.000000       1.000000
# 50%     62.000000    2.000000        2.000000    1.000000       2.000000
# 75%     69.000000    2.000000        2.000000    2.000000       2.000000
# max     87.000000    2.000000        2.000000    2.000000       2.000000
#
#        CHRONIC_DISEASE    ALLERGY     WHEEZING  ALCOHOL_CONSUMING    COUGHING  \
# count       309.000000  309.000000  309.000000         309.000000  309.000000
# mean          1.504854    1.556634    1.556634           1.556634    1.579288
# ...

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC_DISEASE        309 non-null    int64
#  7   ALLERGY                309 non-null    int64
#  8   WHEEZING               309 non-null    int64
#  9   ALCOHOL_CONSUMING      309 non-null    int64
#  10  COUGHING               309 non-null    int64
#  11  SHORTNESS_OF_BREATH    309 non-null    int64
#  12  SWALLOWING_DIFFICULTY  309 non-null    int64
#  13  CHEST_PAIN             309 non-null    int64
#  14  RESULT                 309 non-null    object
# ...

# %%
all_features = [name for name in mydata.columns if mydata[name].dtype == 'object']
all_features
# Out:
# ['GENDER', 'RESULT']

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in list(all_features):
    mydata[i]=le.fit_transform(mydata[i])
for x in all_features:
  print(x," = ",mydata[x].unique())
# Out:
# GENDER  =  [1 0]
# RESULT  =  [1 0]

# %%
mydata.head(10)
# Out:
#    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0       1   69        1               2        2              1
# 1       1   74        2               1        1              1
# 2       0   59        1               1        1              2
# 3       1   63        2               2        2              1
# 4       0   63        1               2        1              1
# 5       0   75        1               2        1              1
# 6       1   52        2               1        1              1
# 7       0   51        2               2        2              2
# 8       0   68        2               1        2              1
# 9       1   53        2               2        2              2
#
#    CHRONIC_DISEASE  ALLERGY   WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                1         1         2                  2         2
# 1                2         2         1                  1         1
# ...

# %%
from sklearn.feature_selection import chi2
X = mydata.drop('RESULT',axis=1)
y = mydata['RESULT']
chi_scores = chi2(X,y)
chi_scores
# Out:
# (array([0.66489923, 2.65148811, 0.16461397, 1.58710195, 1.08315519,
#         1.78718133, 0.63118463, 5.26296889, 3.04472698, 4.07844235,
#         2.9462817 , 0.15992178, 3.53345382, 1.77692485]),
#  array([0.41483564, 0.10345301, 0.68494359, 0.20774067, 0.29799279,
#         0.18126997, 0.42692112, 0.02178383, 0.08099973, 0.04343368,
#         0.08607539, 0.68922854, 0.06014238, 0.18252739]))

# %%
p_values = pd.Series(chi_scores[1],index = X.columns)
p_values.sort_values(ascending = True , inplace = True)
p_values
# Out:
# ALLERGY                  0.021784
# ALCOHOL_CONSUMING        0.043434
# SWALLOWING_DIFFICULTY    0.060142
# WHEEZING                 0.081000
# COUGHING                 0.086075
# AGE                      0.103453
# PEER_PRESSURE            0.181270
# CHEST_PAIN               0.182527
# YELLOW_FINGERS           0.207741
# ANXIETY                  0.297993
# GENDER                   0.414836
# CHRONIC_DISEASE          0.426921
# SMOKING                  0.684944
# SHORTNESS_OF_BREATH      0.689229
# dtype: float64

# %%
p_values.plot.bar(figsize = (6,4), cmap="coolwarm")
plt.title('Chi2 test for feature selection', size=14)
# Out:
# Text(0.5, 1.0, 'Chi2 test for feature selection')

# %%
X = mydata[['PEER_PRESSURE','CHEST_PAIN','YELLOW_FINGERS','ANXIETY','GENDER','CHRONIC_DISEASE','SMOKING','SHORTNESS_OF_BREATH']]
y = mydata['RESULT']

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) #70:30

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X_new, y_new = sm.fit_resample(X_train, y_train)
print(f'''Shape of X before SMOTE: {X_train.shape}
Shape of X after SMOTE: {X_new.shape}''')
print('\nBalance of lung cancer and normal (%):')
y_new.value_counts(normalize=True) * 100
# Out:
# Shape of X before SMOTE: (216, 8)
# Shape of X after SMOTE: (372, 8)
#
# Balance of lung cancer and normal (%):
# 1    50.0
# 0    50.0
# Name: RESULT, dtype: float64

# %%
#การสร้างแบบจำลองต้นไม้ตัดสินใจ
modelDTree = DecisionTreeClassifier(random_state=100)

#การฝึกสอนข้อมูล
modelDTree.fit(X_new,y_new)

#การทำนายข้อมูล
predictions = modelDTree.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
print(accuracy_score(y_test, predictions))
# Out:
# [[ 4  5]
#  [12 72]]
#               precision    recall  f1-score   support
#
#            0       0.25      0.44      0.32         9
#            1       0.94      0.86      0.89        84
#
#     accuracy                           0.82        93
#    macro avg       0.59      0.65      0.61        93
# weighted avg       0.87      0.82      0.84        93
#
# 0.8172043010752689

# %%
from sklearn.tree import export_graphviz
from sklearn import tree
import graphviz
cols = list(X_train.columns.values)
dot_data = tree.export_graphviz(modelDTree, out_file=None,feature_names  = cols)
graph = graphviz.Source(dot_data, format="png")
graph

# %%
graph.render("modelDtree")
'modelDtree.png'
# Out:
# 'modelDtree.png'

# %%
test_lungcancer= pd.read_csv('/content/sample_data/testlungcancer.csv')
test_lungcancer.head()
# Out:
#    PEER_PRESSURE  CHEST_PAIN  YELLOW_FINGERS  ANXIETY  GENDER  \
# 0              1           2               2        2       1
# 1              1           2               1        1       1
# 2              2           2               1        1       0
#
#    CHRONIC_DISEASE  SMOKING  SHORTNESS_OF_BREATH
# 0                1        1                    2
# 1                2        2                    2
# 2                1        1                    2

# %%
test_predict = modelDTree.predict(X=test_lungcancer)
print(test_predict)
# Out:
# [1 1 0]
